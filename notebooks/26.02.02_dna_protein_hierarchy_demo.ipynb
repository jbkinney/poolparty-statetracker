# %%
import poolparty as pp; pp.init()
from poolparty.types import Seq, DnaSeq, ProteinSeq

print("=== Seq class hierarchy ===")
print(f"Seq (base): VALID_CHARS = {Seq.VALID_CHARS}")
print(f"DnaSeq: VALID_CHARS = {''.join(sorted(list(DnaSeq.VALID_CHARS)))}")
print(f"ProteinSeq: VALID_CHARS = {''.join(sorted(list(ProteinSeq.VALID_CHARS)))}")

print("\n=== DnaSeq: DNA-specific methods ===")
dna_seq = DnaSeq.from_string("ACGT")
print(f"DnaSeq: {dna_seq.string}")
print(f"DnaSeq.reversed() (reverse complement): {dna_seq.reversed().string}")
print(f"DnaSeq.rc() (alias): {dna_seq.rc().string}")

print("\n=== DnaSeq supports IUPAC codes for rc() ===")
iupac_seq = DnaSeq.from_string("ACGTN")
print(f"IUPAC sequence: {iupac_seq.string}")
print(f"rc() with IUPAC: {iupac_seq.rc().string}")

print("\n=== DnaPool: DNA-specific operations ===")
dna = pp.from_seq("ATGAAATGA")
print(f"Type: {type(dna).__name__}")
dna.print_library()

print("DnaPool.rc() - reverse complement")
dna.rc().print_library()

print("DnaPool.translate() - returns ProteinPool")
protein = dna.translate()
print(f"Type: {type(protein).__name__}")
protein.print_library()

print("=== ProteinPool: 3-letter amino acid output ===")
protein.print_library(chars_per_aa=3, aa_separator="-")

print("=== DnaPool.mutagenize() returns DnaPool ===")
mutated_dna = pp.from_seq("ACGT").mutagenize(num_mutations=1, num_states=4, mode="sequential")
print(f"Type: {type(mutated_dna).__name__}")
mutated_dna.print_library()

print("=== State operations preserve pool type ===")
print("ProteinPool * 2 returns ProteinPool")
repeated = protein * 2
print(f"Type: {type(repeated).__name__}")
repeated.print_library()

print("=== Pool hierarchy ===")
print(f"Pool base class: {pp.Pool.__name__}")
print(f"DnaPool inherits from Pool: {issubclass(pp.DnaPool, pp.Pool)}")
print(f"ProteinPool inherits from Pool: {issubclass(pp.ProteinPool, pp.Pool)}")
# Out:
# === Seq class hierarchy ===
# Seq (base): VALID_CHARS = frozenset()
# DnaSeq: VALID_CHARS = ABCDGHKMNRSTUVWYabcdghkmnrstuvwy
# ProteinSeq: VALID_CHARS = *ACDEFGHIKLMNPQRSTVWYacdefghiklmnpqrstvwy
#
# === DnaSeq: DNA-specific methods ===
# DnaSeq: ACGT
# DnaSeq.reversed() (reverse complement): ACGT
# DnaSeq.rc() (alias): ACGT
#
# === DnaSeq supports IUPAC codes for rc() ===
# IUPAC sequence: ACGTN
# rc() with IUPAC: NACGT
#
# === DnaPool: DNA-specific operations ===
# Type: DnaPool
# pool[0]: seq_length=9, num_states=1
# state  seq
#     0  ATGAAATGA
#
# DnaPool.rc() - reverse complement
# pool[1]: seq_length=9, num_states=1
# state  seq
#     0  TCATTTCAT
#
# DnaPool.translate() - returns ProteinPool
# Type: ProteinPool
# pool[2]: seq_length=3, num_states=1
# state  seq
#     0  MK*
#
# === ProteinPool: 3-letter amino acid output ===
# pool[2]: seq_length=3, num_states=1
# state  seq
#     0  Met-Lys-***
#
# === DnaPool.mutagenize() returns DnaPool ===
# Type: DnaPool
# pool[4]: seq_length=4, num_states=4
# state  seq
#     0  CCGT
#     1  GCGT
#     2  TCGT
#     3  AAGT
#
# === State operations preserve pool type ===
# ProteinPool * 2 returns ProteinPool
# Type: ProteinPool
# pool[5]: seq_length=3, num_states=2
# state  seq
#     0  MK*
#     1  MK*
#
# === Pool hierarchy ===
# Pool base class: Pool
# DnaPool inherits from Pool: True
# ProteinPool inherits from Pool: True
