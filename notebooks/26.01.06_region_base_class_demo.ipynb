# %%
import poolparty as pp; pp.init()

# Demo: region and remove_marker parameters work consistently across operation types
# These parameters are now handled by the Operation base class

bg = pp.from_seq('AAAA<region>acAC</region>TTTT')
print("Source sequence with marker:"); bg.print_library()

# 1. FixedOp (via upper) - with and without marker removal
print("1. upper() with region='region':")
bg.upper(region='region').print_library()
print("   upper() with region='region', remove_marker=False:")
bg.upper(region='region', remove_marker=False).print_library()
print("   upper() with region='region', remove_marker=True:")
bg.upper(region='region', remove_marker=True).print_library()

# 2. shuffle_seq with region and remove_marker
print("2. shuffle_seq() with region='region', remove_marker=True:")
bg.shuffle_seq(region='region', remove_marker=True).print_library(seed=42)
print("   shuffle_seq() with region='region', remove_marker=False:")
bg.shuffle_seq(region='region', remove_marker=False).print_library(seed=42)

# 3. mutagenize with region and remove_marker
print("3. mutagenize() with region='region', remove_marker=True:")
bg.mutagenize(num_mutations=1, region='region', remove_marker=True).print_library(seed=42)
print("   mutagenize() with region='region', remove_marker=False:")
bg.mutagenize(num_mutations=1, region='region', remove_marker=False).print_library(seed=42)

# 4. All operations also support [start, stop] interval syntax for region
print("4. Using [start, stop] interval syntax (positions 4-8):")
bg.upper('aaaacccctttt', region=[4, 8]).print_library()
# Out:
# Source sequence with marker:
# pool[0]: seq_length=12, num_values=1
# state  seq
#     0  AAAA<region>acAC</region>TTTT
#
# 1. upper() with region='region':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 # 1. FixedOp (via upper) - with and without marker removal
#      10 print("1. upper() with region='region':")
# ---> 11 bg.upper(region='region').print_library()
#      12 print("   upper() with region='region', remove_marker=False:")
#      13 bg.upper(region='region', remove_marker=False).print_library()
#
# File <@beartype(poolparty.ops_container.OpsContainer.upper) at 0x11d994790>:143, in upper(__beartype_object_4790457280, __beartype_get_violation, __beartype_conf, __beartype_object_4791064832, __beartype_object_4790672384, __beartype_object_140662928030032, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# TypeError: OpsContainer.upper() got an unexpected keyword argument 'region'
