# %%
import poolparty as pp
pp.init()

# Create a pool with mutagenize operation
pool = pp.from_seq('ATCGATCGATCG').mutagenize(num_mutations=2, mode='sequential', prefix='mut')

# Generate library with design cards (default)
print("=== With design cards (default) ===")
df_with_cards = pool.generate_library(num_cycles=1, report_design_cards=True)
print(f"Number of columns: {len(df_with_cards.columns)}")
print(f"Columns: {list(df_with_cards.columns)}")
print(f"\nFirst 3 sequences:")
print(df_with_cards[['seq']].head(3))

# Toggle cards off - suppresses design card computation at the source
pp.toggle_cards(on=False)

# Generate library with cards suppressed - no design card metadata
print("\n=== With pp.toggle_cards(on=False) ===")
df_no_cards = pool.generate_library(num_cycles=1, report_design_cards=True)
print(f"Number of columns: {len(df_no_cards.columns)}")
print(f"Columns: {list(df_no_cards.columns)}")
print(f"\nFirst 3 sequences:")
print(df_no_cards[['seq']].head(3))

# Verify styles are still computed (toggle_cards is independent of toggle_styles)
print(f"\nInline styles preserved: {df_no_cards['_inline_styles'].iloc[0] is not None}")

# Summary
print(f"\n=== Summary ===")
print(f"With design cards: {len(df_with_cards.columns)} columns")
print(f"With toggle_cards(on=False): {len(df_no_cards.columns)} columns")
print(f"All design card metadata eliminated (keys, states, pool seqs)")
print(f"Only 'seq' and '_inline_styles' remain for production use")
# Out:
# === With design cards (default) ===
# Number of columns: 11
# Columns: ['name', 'seq', 'pool[1].seq', 'pool[0].seq', 'pool[1].state', 'pool[0].state', 'op[1]:mutagenize.state', 'op[1]:mutagenize.key.positions', 'op[1]:mutagenize.key.wt_chars', 'op[1]:mutagenize.key.mut_chars', '_inline_styles']
#
# First 3 sequences:
#             seq
# 0  CACGATCGATCG
# 1  CCCGATCGATCG
# 2  CGCGATCGATCG
#
# === With pp.toggle_cards(on=False) ===
# Number of columns: 3
# Columns: ['name', 'seq', '_inline_styles']
#
# First 3 sequences:
#             seq
# 0  CACGATCGATCG
# 1  CCCGATCGATCG
# 2  CGCGATCGATCG
#
# Inline styles preserved: True
#
# === Summary ===
# With design cards: 11 columns
# With toggle_cards(on=False): 3 columns
# All design card metadata eliminated (keys, states, pool seqs)
# Only 'seq' and '_inline_styles' remain for production use
