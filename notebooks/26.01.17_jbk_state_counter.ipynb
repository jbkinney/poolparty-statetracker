# %%
from statecounter import Counter, Manager, product, stack

with Manager():
    A = Counter(num_states=3, name='A')
    B = A[0:2].named('B')  # States 0, 1 of A
    C = A[1:3].named('C')  # States 1, 2 of A
    D = stack([B, C]).named('D')
    display(D.get_iteration_df().T)

    # State 0 of D → B state 0 → A state 0 ✓
    # State 2 of D → C state 0 → A state 1
    # But what if we try to set both B and C active?

    # This would conflict: A can't be both 0 and 1
# Out:
# D     0     1     2     3
# B     0     1  None  None
# A     0     1     1     2
# C  None  None     0     1
