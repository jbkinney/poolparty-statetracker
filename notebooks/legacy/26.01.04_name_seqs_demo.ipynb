# %%
import poolparty as pp
pp.init()

source = (
    pp.from_seqs(['AAAA', 'CCCC', 'GGGG'], mode='sequential', name_prefix='gene_')
    .repeat_states(5, name_prefix='v')
    .print_library(num_cycles=1)
)
# Out:
# pool[1]: seq_length=4, num_states=15
# state  name  seq
#     0  gene_0.v0  AAAA
#     1  gene_1.v1  CCCC
#     2  gene_2.v2  GGGG
#     3  gene_0.v3  AAAA
#     4  gene_1.v4  CCCC
#     5  gene_2.v5  GGGG
#     6  gene_0.v6  AAAA
#     7  gene_1.v7  CCCC
#     8  gene_2.v8  GGGG
#     9  gene_0.v9  AAAA
#    10  gene_1.v10  CCCC
#    11  gene_2.v11  GGGG
#    12  gene_0.v12  AAAA
#    13  gene_1.v13  CCCC
#    14  gene_2.v14  GGGG
