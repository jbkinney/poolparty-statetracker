# %%
import poolparty as pp; pp.init()
import pandas as pd

# Create a pool with a marked region
print('base pool')
pool = pp.from_seq('AAAA<reg>ACAT</reg>CCCC').print_library()

# Base ops via OpsContainer (use native region support)
print('mutagenize')
pool.mutagenize('reg', num_mutations=1, mode='sequential').print_library()
print('shuffle_seq')
pool.shuffle_seq('reg').print_library()

# Scan ops via OpsContainer (use native region support)
print('deletion_scan')
pool.deletion_scan('reg', deletion_length=2, mode='sequential').print_library()
print('insertion_scan')
pool.insertion_scan('reg', 'GG', mode='sequential').print_library()
print('replacement_scan')
pool.replacement_scan('reg', 'GG', mode='sequential').print_library()
print('mutagenize_scan')
pool.mutagenize_scan('reg', mutagenize_length=2, num_mutations=1, mode='sequential').print_library()
print('shuffle_scan')
pool.shuffle_scan('reg', shuffle_length=2, mode='sequential').print_library()

# Insert operations via OpsContainer (use native bg_pool/region support)
print('insert_from_iupac')
pool.insert_from_iupac('reg', 'RY', mode='sequential').print_library()
print('insert_from_motif')
prob_df = pd.DataFrame({'A': [0.5, 0.5], 'C': [0.5, 0.5], 'G': [0, 0], 'T': [0, 0]})
pool.insert_from_motif('reg', prob_df).print_library()
print('insert_kmers')
pool.insert_kmers('reg', length=2, mode='sequential').print_library()

# Demonstrate remove_marker=False preserves markers
print('mutagenize_remove_marker_true')
pool.mutagenize('reg', num_mutations=1, remove_marker=True, mode='sequential').print_library()
# Out:
# base pool
# pool[0]: seq_length=12, num_values=1
# state  seq
#     0  AAAA<reg>ACAT</reg>CCCC
#
# mutagenize
# pool[1]: seq_length=12, num_values=36
# state  seq
#     0  AAAA<reg>cCAT</reg>CCCC
#     1  AAAA<reg>gCAT</reg>CCCC
#     2  AAAA<reg>tCAT</reg>CCCC
#     3  AAAA<reg>AaAT</reg>CCCC
#     4  AAAA<reg>AgAT</reg>CCCC
#     5  AAAA<reg>AtAT</reg>CCCC
#     6  AAAA<reg>ACcT</reg>CCCC
#     7  AAAA<reg>ACgT</reg>CCCC
#     8  AAAA<reg>ACtT</reg>CCCC
#     9  AAAA<reg>ACAa</reg>CCCC
#    10  AAAA<reg>ACAc</reg>CCCC
#    11  AAAA<reg>ACAg</reg>CCCC
#    12  AAAA<reg>cCAT</reg>CCCC
#    13  AAAA<reg>gCAT</reg>CCCC
#    14  AAAA<reg>tCAT</reg>CCCC
#    15  AAAA<reg>AaAT</reg>CCCC
#    16  AAAA<reg>AgAT</reg>CCCC
#    17  AAAA<reg>AtAT</reg>CCCC
#    18  AAAA<reg>ACcT</reg>CCCC
#    19  AAAA<reg>ACgT</reg>CCCC
#    20  AAAA<reg>ACtT</reg>CCCC
#    21  AAAA<reg>ACAa</reg>CCCC
#    22  AAAA<reg>ACAc</reg>CCCC
#    23  AAAA<reg>ACAg</reg>CCCC
#    24  AAAA<reg>cCAT</reg>CCCC
#    25  AAAA<reg>gCAT</reg>CCCC
#    26  AAAA<reg>tCAT</reg>CCCC
#    27  AAAA<reg>AaAT</reg>CCCC
#    28  AAAA<reg>AgAT</reg>CCCC
#    29  AAAA<reg>AtAT</reg>CCCC
#    30  AAAA<reg>ACcT</reg>CCCC
#    31  AAAA<reg>ACgT</reg>CCCC
#    32  AAAA<reg>ACtT</reg>CCCC
#    33  AAAA<reg>ACAa</reg>CCCC
#    34  AAAA<reg>ACAc</reg>CCCC
#    35  AAAA<reg>ACAg</reg>CCCC
#
# shuffle_seq
# pool[2]: seq_length=12, num_values=1
# state  seq
#     0  AAAA<reg>aact</reg>CCCC
#
# deletion_scan
# pool[7]: seq_length=None, num_values=3
# state  seq
#     0  AAAA<reg>--AT</reg>CCCC
#     1  AAAA<reg>A--T</reg>CCCC
#     2  AAAA<reg>AC--</reg>CCCC
#
# insertion_scan
# pool[13]: seq_length=None, num_values=5
# state  seq
#     0  AAAA<reg>ggACAT</reg>CCCC
#     1  AAAA<reg>AggCAT</reg>CCCC
#     2  AAAA<reg>ACggAT</reg>CCCC
#     3  AAAA<reg>ACAggT</reg>CCCC
#     4  AAAA<reg>ACATgg</reg>CCCC
#
# replacement_scan
# pool[19]: seq_length=None, num_values=3
# state  seq
#     0  AAAA<reg>ggAT</reg>CCCC
#     1  AAAA<reg>AggT</reg>CCCC
#     2  AAAA<reg>ACgg</reg>CCCC
#
# mutagenize_scan
# pool[25]: seq_length=None, num_values=3
# state  seq
#     0  AAAA<reg>AgAT</reg>CCCC
#     1  AAAA<reg>ACcT</reg>CCCC
#     2  AAAA<reg>ACcT</reg>CCCC
#
# shuffle_scan
# pool[32]: seq_length=None, num_values=3
# state  seq
#     0  AAAA<reg>CAAT</reg>CCCC
#     1  AAAA<reg>AACT</reg>CCCC
#     2  AAAA<reg>ACTA</reg>CCCC
#
# insert_from_iupac
# pool[33]: seq_length=2, num_values=4
# state  seq
#     0  AAAA<reg>ac</reg>CCCC
#     1  AAAA<reg>at</reg>CCCC
#     2  AAAA<reg>gc</reg>CCCC
#     3  AAAA<reg>gt</reg>CCCC
#
# insert_from_motif
# pool[34]: seq_length=2, num_values=1
# state  seq
#     0  AAAA<reg>ca</reg>CCCC
#
# insert_kmers
# pool[35]: seq_length=2, num_values=16
# state  seq
#     0  AAAA<reg>aa</reg>CCCC
#     1  AAAA<reg>ac</reg>CCCC
#     2  AAAA<reg>ag</reg>CCCC
#     3  AAAA<reg>at</reg>CCCC
#     4  AAAA<reg>ca</reg>CCCC
#     5  AAAA<reg>cc</reg>CCCC
#     6  AAAA<reg>cg</reg>CCCC
#     7  AAAA<reg>ct</reg>CCCC
#     8  AAAA<reg>ga</reg>CCCC
#     9  AAAA<reg>gc</reg>CCCC
#    10  AAAA<reg>gg</reg>CCCC
#    11  AAAA<reg>gt</reg>CCCC
#    12  AAAA<reg>ta</reg>CCCC
#    13  AAAA<reg>tc</reg>CCCC
#    14  AAAA<reg>tg</reg>CCCC
#    15  AAAA<reg>tt</reg>CCCC
#
# mutagenize_remove_marker_true
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 37
#      35 # Demonstrate remove_marker=False preserves markers
#      36 print('mutagenize_remove_marker_true')
# ---> 37 pool.mutagenize('reg', num_mutations=1, remove_marker=True, mode='sequential').print_library()
#
# File <@beartype(poolparty.ops_container.OpsContainer.mutagenize) at 0x11d944160>:55, in mutagenize(__beartype_get_violation, __beartype_conf, __beartype_object_4790699904, __beartype_args_name_keywordable, __beartype_object_140301229610496, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/github/poolparty-statecounter/poolparty/src/poolparty/ops_container.py:36, in OpsContainer.mutagenize(self, region, remove_tags, **kwargs)
#      34 from .base_ops.mutagenize import mutagenize
#      35 iter_order = kwargs.pop('iter_order', None)
# ---> 36 return mutagenize(self.pool, region=region, remove_marker=remove_tags, op_iter_order=iter_order, **kwargs)
#
# TypeError: poolparty.base_ops.mutagenize.mutagenize() got multiple values for keyword argument 'remove_marker'
