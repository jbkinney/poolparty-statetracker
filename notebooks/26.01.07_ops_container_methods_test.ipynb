# %%
import poolparty as pp; pp.init()

bg_pool = pp.from_seq('AAAAAAAAAAAAAAAA')

bg_pool.mutagenize(num_mutations=1, mode='sequential')

bg_pool.deletion_scan(deletion_length=3, mode='sequential')

bg_pool.insertion_scan(ins_pool=pp.from_seq('TTTT'), mode='sequential')

bg_pool.replacement_scan(ins_pool=pp.from_seq('TTTT'), mode='sequential')

bg_pool.mutagenize_scan(mutagenize_length=5, num_mutations=1, mode='sequential', spacer_str='.').print_library()
# Out:
# pool[13]: seq_length=None, num_values=180
# state  seq
#     0  .cAAAA.AAAAAAAAAAA
#     1  .gAAAA.AAAAAAAAAAA
#     2  .tAAAA.AAAAAAAAAAA
#     3  .AcAAA.AAAAAAAAAAA
#     4  .AgAAA.AAAAAAAAAAA
#     5  .AtAAA.AAAAAAAAAAA
#     6  .AAcAA.AAAAAAAAAAA
#     7  .AAgAA.AAAAAAAAAAA
#     8  .AAtAA.AAAAAAAAAAA
#     9  .AAAcA.AAAAAAAAAAA
#    10  .AAAgA.AAAAAAAAAAA
#    11  .AAAtA.AAAAAAAAAAA
#    12  .AAAAc.AAAAAAAAAAA
#    13  .AAAAg.AAAAAAAAAAA
#    14  .AAAAt.AAAAAAAAAAA
#    15  A.cAAAA.AAAAAAAAAA
#    16  A.gAAAA.AAAAAAAAAA
#    17  A.tAAAA.AAAAAAAAAA
#    18  A.AcAAA.AAAAAAAAAA
#    19  A.AgAAA.AAAAAAAAAA
#    20  A.AtAAA.AAAAAAAAAA
#    21  A.AAcAA.AAAAAAAAAA
#    22  A.AAgAA.AAAAAAAAAA
#    23  A.AAtAA.AAAAAAAAAA
#    24  A.AAAcA.AAAAAAAAAA
#    25  A.AAAgA.AAAAAAAAAA
#    26  A.AAAtA.AAAAAAAAAA
#    27  A.AAAAc.AAAAAAAAAA
#    28  A.AAAAg.AAAAAAAAAA
#    29  A.AAAAt.AAAAAAAAAA
#    30  AA.cAAAA.AAAAAAAAA
#    31  AA.gAAAA.AAAAAAAAA
#    32  AA.tAAAA.AAAAAAAAA
# ...
