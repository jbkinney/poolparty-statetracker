# %%
import poolparty as pp; pp.init()

# Mutagenize with num_mutations (sequential mode)
pp.mutagenize('ACGTACGTACGT', num_mutations=2, mode='sequential').print_library()

# Mutagenize with mutation_rate (random mode)
pp.mutagenize('ACGTACGTACGT', mutation_rate=0.2, mode='random').generate_library(num_seqs=5)
# Out:
# pool[1]: seq_length=12, num_states=594
# state  seq
#     0  CAGTACGTACGT
#     1  CGGTACGTACGT
#     2  CTGTACGTACGT
#     3  GAGTACGTACGT
#     4  GGGTACGTACGT
#     5  GTGTACGTACGT
#     6  TAGTACGTACGT
#     7  TGGTACGTACGT
#     8  TTGTACGTACGT
#     9  CCATACGTACGT
#    10  CCCTACGTACGT
#    11  CCTTACGTACGT
#    12  GCATACGTACGT
#    13  GCCTACGTACGT
#    14  GCTTACGTACGT
#    15  TCATACGTACGT
#    16  TCCTACGTACGT
#    17  TCTTACGTACGT
#    18  CCGAACGTACGT
#    19  CCGCACGTACGT
#    20  CCGGACGTACGT
#    21  GCGAACGTACGT
#    22  GCGCACGTACGT
#    23  GCGGACGTACGT
#    24  TCGAACGTACGT
#    25  TCGCACGTACGT
#    26  TCGGACGTACGT
#    27  CCGTCCGTACGT
#    28  CCGTGCGTACGT
#    29  CCGTTCGTACGT
#    30  GCGTCCGTACGT
#    31  GCGTGCGTACGT
#    32  GCGTTCGTACGT
#    33  TCGTCCGTACGT
#    34  TCGTGCGTACGT
#    35  TCGTTCGTACGT
#    36  CCGTAAGTACGT
#    37  CCGTAGGTACGT
#    38  CCGTATGTACGT
#    39  GCGTAAGTACGT
#    40  GCGTAGGTACGT
#    41  GCGTATGTACGT
#    42  TCGTAAGTACGT
# ...
